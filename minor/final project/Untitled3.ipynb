# %%
from arch import arch_model

# %%
#b1=['C:\\Program Files\\Python37\\Lib\\site-packages']+b

# %%
#sys.path=b1

# %%
import datetime as dt
import pandas_datareader.data as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-eeb6774a98f7> in <module>
#       1 import datetime as dt
# ----> 2 import pandas_datareader.data as web
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
#from arch import arch_model

# %%
from arch import ConstantMean, GARCH, Normal
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-032dfbc11d05> in <module>()
# ----> 1 from arch import ConstantMean, GARCH, Normal
#
# ImportError: cannot import name 'ConstantMean' from 'arch' (C:\ProgramData\Anaconda3\lib\site-packages\arch\__init__.py)

# %%
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2014, 1, 1)

# %%
sp500 = web.DataReader('^GSPC', 'yahoo', start=start, end=end)
returns = 100 * sp500['Adj Close'].pct_change().dropna()
am = arch_model(returns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-63833d36596b> in <module>()
# ----> 1 sp500 = web.DataReader('^GSPC', 'yahoo', start=start, end=end)
#       2 returns = 100 * sp500['Adj Close'].pct_change().dropna()
#       3 am = arch_model(returns)
#
# NameError: name 'web' is not defined

# %%
from pandas import data, wb # becomes
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-e05e9ad567ea> in <module>()
# ----> 1 from pandas import data, wb # becomes
#
# ImportError: cannot import name 'data' from 'pandas' (C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py)

# %%
import pandas as pd

# %%
import datetime as dt
import pandas_datareader as web
web.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2010-01-01  3.73
# 2010-02-01  3.69
# 2010-03-01  3.73
# 2010-04-01  3.85
# 2010-05-01  3.42
# 2010-06-01  3.20
# 2010-07-01  3.01
# 2010-08-01  2.70
# 2010-09-01  2.65
# 2010-10-01  2.54
# 2010-11-01  2.76
# 2010-12-01  3.29
# 2011-01-01  3.39
# 2011-02-01  3.58
# 2011-03-01  3.41
# 2011-04-01  3.46
# 2011-05-01  3.17
# 2011-06-01  3.00
# 2011-07-01  3.00
# 2011-08-01  2.30
# 2011-09-01  1.98
# 2011-10-01  2.15
# 2011-11-01  2.01
# 2011-12-01  1.98
# 2012-01-01  1.97
# 2012-02-01  1.97
# 2012-03-01  2.17
# 2012-04-01  2.05
# 2012-05-01  1.80
# 2012-06-01  1.62
# ...          ...
# 2016-07-01  1.50
# 2016-08-01  1.56
# 2016-09-01  1.63
# 2016-10-01  1.76
# 2016-11-01  2.14
# 2016-12-01  2.49
# 2017-01-01  2.43
# 2017-02-01  2.42
# 2017-03-01  2.48
# 2017-04-01  2.30
# 2017-05-01  2.30
# 2017-06-01  2.19
# 2017-07-01  2.32
# 2017-08-01  2.21
# 2017-09-01  2.20
# 2017-10-01  2.36
# 2017-11-01  2.35
# 2017-12-01  2.40
# 2018-01-01  2.58
# 2018-02-01  2.86
# 2018-03-01  2.84
# 2018-04-01  2.87
# 2018-05-01  2.98
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
#
# [108 rows x 1 columns]

# %%
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2014, 1, 1)
sp500 = web.DataReader('^GSPC', 'yahoo', start=start, end=end)
returns = 100 * sp500['Adj Close'].pct_change().dropna()
am = arch_model(returns)

# %%
am2 = arch_model(returns, mean='AR', lags=2, vol='harch', p=[1,5, 22])

# %%
summary(am2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-86a0393ff788> in <module>()
# ----> 1 summary(am2)
#
# NameError: name 'summary' is not defined

# %%
am = arch_model(returns, mean='zero', p=1, o=1, q=1,
... power=1.0, dist='StudentsT')

# %%
import pandas as pd
from arch import arch_model
am = arch_model(None,mean='HAR',lags=[1,5,22],vol='Constant')
sim_data = am.simulate([0.1,0.4,0.3,0.2,1.0], 250)
sim_data.index = pd.date_range('2000-01-01',periods=250)
am = arch_model(sim_data['data'],mean='HAR',lags=[1,5,22],vol='Constant')
res = am.fit()
fig = res.hedgehog_plot(type='mean')

# %%
from arch import Constant_Mean
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-71ccf13b2234> in <module>()
# ----> 1 from arch import Constant_Mean
#
# ImportError: cannot import name 'Constant_Mean' from 'arch' (C:\ProgramData\Anaconda3\lib\site-packages\arch\__init__.py)

# %%
res=am.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 5159.583236619886
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 5156.097598740948
# Iteration:      3,   Func. Count:     24,   Neg. LLF: 5152.299896533299
# Iteration:      4,   Func. Count:     31,   Neg. LLF: 5146.4753110022275
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 5143.863365356461
# Iteration:      6,   Func. Count:     45,   Neg. LLF: 5143.020952355564
# Iteration:      7,   Func. Count:     52,   Neg. LLF: 5142.241046294943
# Iteration:      8,   Func. Count:     60,   Neg. LLF: 5142.071372040911
# Iteration:      9,   Func. Count:     67,   Neg. LLF: 5141.416648698332
# Iteration:     10,   Func. Count:     73,   Neg. LLF: 5141.392119616873
# Iteration:     11,   Func. Count:     79,   Neg. LLF: 5141.390235769537
# Iteration:     12,   Func. Count:     85,   Neg. LLF: 5141.39023050684
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5141.390230505602
#             Iterations: 12
#             Function evaluations: 85
#             Gradient evaluations: 12

# %%
from arch import arch_model
am = arch_model(None)
sim_data = am.simulate([0.0, 0.01, 0.07, 0.92], 2520)
am = arch_model(sim_data['data'])
res = am.fit(update_freq=0, disp='off')
fig = res.plot()

# %%
fig = res.plot(annualize='D')

# %%
fig = res.plot(scale=360)

# %%
print(res.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   data   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -3331.77
# Distribution:                  Normal   AIC:                           6671.53
# Method:            Maximum Likelihood   BIC:                           6694.86
#                                         No. Observations:                 2520
# Date:                Sat, Jan 26 2019   Df Residuals:                     2516
# Time:                        23:37:38   Df Model:                            4
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0152  1.609e-02     -0.944      0.345 [-4.674e-02,1.635e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      6.3531e-03  2.428e-03      2.616  8.893e-03 [1.593e-03,1.111e-02]
# alpha[1]       0.0700  8.431e-03      8.303  1.014e-16 [5.348e-02,8.653e-02]
# beta[1]        0.9258  8.645e-03    107.089      0.000     [  0.909,  0.943]
# ============================================================================
#
# Covariance estimator: robust

# %%
import pandas as pd
>>> from arch import arch_model
>>> am = arch_model(None,mean='HAR',lags=[1,5,22],vol='Constant')
>>> sim_data = am.simulate([0.1,0.4,0.3,0.2,1.0], 250)
>>> sim_data.index = pd.date_range('2000-01-01',periods=250)
>>> am = arch_model(sim_data['data'],mean='HAR',lags=[1,5,22],vol='Constant')
>>> res = am.fit()
>>> fig = res.hedgehog_plot(type='mean')

# %%
#sim_data
#res.summary()

# %%
am = arch_model(None)
>>> sim_data = am.simulate([0.0, 0.01, 0.07, 0.92], 2520)
>>> am = arch_model(sim_data['data'], p=2,q=2)
>>> res = am.fit(update_freq=0, disp='off')
>>> fig = res.plot()

# %%
res
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   data   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -3745.61
# Distribution:                  Normal   AIC:                           7503.22
# Method:            Maximum Likelihood   BIC:                           7538.21
#                                         No. Observations:                 2520
# Date:                Sun, Jan 27 2019   Df Residuals:                     2514
# Time:                        16:23:58   Df Model:                            6
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0177  1.894e-02     -0.934      0.350 [-5.481e-02,1.943e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0113  4.972e-03      2.282  2.252e-02  [1.599e-03,2.109e-02]
# alpha[1]       0.0200  1.986e-02      1.005      0.315 [-1.897e-02,5.887e-02]
# alpha[2]       0.0787  2.127e-02      3.699  2.161e-04    [3.701e-02,  0.120]
# beta[1]        0.3954      0.149      2.649  8.081e-03      [  0.103,  0.688]
# beta[2]        0.4997      0.140      3.579  3.453e-04      [  0.226,  0.773]
# =============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0xe259cf8

# %%
>>> am = arch_model(sim_data['data'], p=1,q=2)
>>> res = am.fit(update_freq=0, disp='off')
>>> fig = res.plot()

# %%
res
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   data   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -3353.62
# Distribution:                  Normal   AIC:                           6717.23
# Method:            Maximum Likelihood   BIC:                           6746.39
#                                         No. Observations:                 2520
# Date:                Sun, Jan 27 2019   Df Residuals:                     2515
# Time:                        16:22:28   Df Model:                            5
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0188  1.690e-02      1.114      0.265 [-1.430e-02,5.196e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0144  5.914e-03      2.434  1.491e-02 [2.806e-03,2.599e-02]
# alpha[1]       0.0728  2.112e-02      3.448  5.646e-04   [3.143e-02,  0.114]
# beta[1]        0.7292      0.352      2.072  3.830e-02   [3.930e-02,  1.419]
# beta[2]        0.1834      0.331      0.554      0.580     [ -0.466,  0.832]
# ============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0xd1e3630

# %%
# ?mean
# Out:
# Object `mean` not found.

# %%
from sklearn.datasets import load_boston
data=load_boston()

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
data.head
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#      95         try:
# ---> 96             return self[key]
#      97         except KeyError:
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0572ccd830ca> in <module>
# ----> 1 data.head
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#      96             return self[key]
#      97         except KeyError:
# ---> 98             raise AttributeError(key)
#      99
#     100     def __setstate__(self, state):
#
# AttributeError: head

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
plt.hist(data.target, bins=30)
plt.xlabel('price ($1000s)')
plt.ylabel('count')
plt.tight_layout()

# %%
data
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#         21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#         35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#         19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#         20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#         23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#         33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#         21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#         20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#         23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#         15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#         17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#         25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#         23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#         32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#         34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#         20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#         26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#         31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#         22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#         42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#         36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#         32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#         20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#         20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#         22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#         21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#         19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#         32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#         18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#         16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#         13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#          7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#         12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#         27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#          8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#          9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#         10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#         15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#         19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#         29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#         20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#         23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]),
#  'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#         'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'),
#  'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n",
#  'filename': '/opt/anaconda3/lib/python3.8/site-packages/sklearn/datasets/data/boston_house_prices.csv'}

# %%
for index, feature_name in enumerate(data.feature_names):
    plt.figure(figsize=(4, 3))
    plt.scatter(data.data[:, index], data.target)
    plt.ylabel('Price', size=15)
    plt.xlabel(feature_name, size=15)
    plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)
expected = y_test
X_test
# Out:
# array([[3.18270e-01, 0.00000e+00, 9.90000e+00, ..., 1.84000e+01,
#         3.90700e+02, 1.83300e+01],
#        [1.36781e+01, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         6.89500e+01, 3.40200e+01],
#        [1.67600e-01, 0.00000e+00, 7.38000e+00, ..., 1.96000e+01,
#         3.96900e+02, 7.20000e+00],
#        ...,
#        [1.23247e+00, 0.00000e+00, 8.14000e+00, ..., 2.10000e+01,
#         3.96900e+02, 1.87200e+01],
#        [1.20830e-01, 0.00000e+00, 2.89000e+00, ..., 1.80000e+01,
#         3.96900e+02, 4.21000e+00],
#        [1.40520e-01, 0.00000e+00, 1.05900e+01, ..., 1.86000e+01,
#         3.85810e+02, 9.38000e+00]])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import mean_absolute_error
MAE=sum(abs(predicted- expected))/ len(y_test)
MSQERR=sum((predicted- expected)**2)/len(y_test)

# %%
plt.figure(figsize=(4, 3))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.tight_layout()

# %%
r2_score(predicted, expected)
# Out:
# 0.4859968157602349

# %% [markdown]
# y=y0+a1*Crim+a2*ZN+ ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf1 = GradientBoostingRegressor()
clf1.fit(X_train, y_train)
predicted = clf1.predict(X_test)
expected = y_test
plt.figure(figsize=(4, 3))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.tight_layout()

# %%
r2_score(predicted, expected)
# Out:
# 0.8153885957017348

# %%
MAE=sum(abs(predicted- expected))/ len(y_test)
MSQERR=sum((predicted- expected)**2)/len(y_test)
print('Gradient boosting: MAE=',MAE, 'MSQERR=', MSQERR )
# Out:
# Gradient boosting: MAE= 2.3447470042975045 MSQERR= 12.17474694969779

# %%
MAE=sum(abs(predicted- expected))/ len(y_test)
MSQERR=sum((predicted- expected)**2)/len(y_test)
print('Lin regression: MAE=',MAE, 'MSQERR=', MSQERR )
# Out:
# Lin regression: MAE= 3.811045925922276 MSQERR= 30.73284291886965

# %%
slapinova@yandex.ru
